# %% [markdown]
# # Spotify song cluster analysis

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sp
from sklearn.preprocessing import scale 
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
import statsmodels.formula.api as smf

from warnings import filterwarnings
filterwarnings('ignore')


import os
for dirname, _, filenames in os.walk(r'C:\Users\79308\Desktop\patel\Cluster\7 Spotify\archive (7)'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:\Users\79308\Desktop\patel\Cluster\7 Spotify\archive (7)\top50.csv

# %%
#Importing Dataset
data=pd.read_csv(r'C:\Users\79308\Desktop\patel\Cluster\7 Spotify\archive (7)/top50.csv', encoding='ISO-8859-1')
data.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# 0      191               4             3          79
# 1      302               8             9          92
# 2      186              12            46          85
# 3      198              12            19          86
# 4      175              45             7          94

# %%
print(data.shape)
# Out:
# (50, 14)

# %%
data=data.dropna(how='all')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   Track.Name        50 non-null     object
#  2   Artist.Name       50 non-null     object
#  3   Genre             50 non-null     object
#  4   Beats.Per.Minute  50 non-null     int64
#  5   Energy            50 non-null     int64
#  6   Danceability      50 non-null     int64
#  7   Loudness..dB..    50 non-null     int64
#  8   Liveness          50 non-null     int64
#  9   Valence.          50 non-null     int64
#  10  Length.           50 non-null     int64
#  11  Acousticness..    50 non-null     int64
#  12  Speechiness.      50 non-null     int64
#  13  Popularity        50 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %%
print(data.groupby('Genre').size())
# Out:
# Genre
# atl hip hop         1
# australian pop      1
# big room            1
# boy band            1
# brostep             2
# canadian hip hop    3
# canadian pop        2
# country rap         2
# dance pop           8
# dfw rap             2
# edm                 3
# electropop          2
# escape room         1
# latin               5
# panamanian pop      2
# pop                 7
# pop house           1
# r&b en espanol      1
# reggaeton           2
# reggaeton flow      2
# trap music          1
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data=data.sort_values(['Unnamed: 0'])
data=data.reindex(data['Unnamed: 0'])
data=data.drop("Unnamed: 0",axis=1)
data.head()
# Out:
#                                    Track.Name    Artist.Name           Genre  \
# Unnamed: 0
# 1                                       China       Anuel AA  reggaeton flow
# 2               boyfriend (with Social House)  Ariana Grande       dance pop
# 3             Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4                 Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
# 5           I Don't Care (with Justin Bieber)     Ed Sheeran             pop
#
#             Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# Unnamed: 0
# 1                      105.0    81.0          79.0            -4.0       8.0
# 2                      190.0    80.0          40.0            -4.0      16.0
# 3                       93.0    65.0          64.0            -8.0       8.0
# 4                      150.0    65.0          58.0            -4.0      11.0
# 5                      102.0    68.0          80.0            -5.0       9.0
#
#             Valence.  Length.  Acousticness..  Speechiness.  Popularity
# Unnamed: 0
# 1               61.0    302.0             8.0           9.0        92.0
# 2               70.0    186.0            12.0          46.0        85.0
# 3               55.0    198.0            12.0          19.0        86.0
# 4               18.0    175.0            45.0           7.0        94.0
# 5               84.0    220.0             9.0           4.0        84.0

# %%
data.describe().T
# Out:
#                   count        mean        std    min    25%    50%    75%  \
# Beats.Per.Minute   49.0  120.122449  31.215403   85.0   96.0  104.0  138.0
# Energy             49.0   64.244898  14.318593   32.0   56.0   68.0   75.0
# Danceability       49.0   71.285714  12.034672   29.0   67.0   73.0   80.0
# Loudness..dB..     49.0   -5.653061   2.077168  -11.0   -7.0   -6.0   -4.0
# Liveness           49.0   14.795918  11.191477    5.0    8.0   11.0   16.0
# Valence.           49.0   54.183673  22.370622   10.0   38.0   55.0   68.0
# Length.            49.0  201.163265  39.522856  115.0  176.0  198.0  218.0
# Acousticness..     49.0   22.530612  19.008882    1.0    9.0   15.0   34.0
# Speechiness.       49.0   12.673469  11.192236    3.0    5.0    7.0   15.0
# Popularity         49.0   87.673469   4.365527   70.0   86.0   88.0   91.0
#
#                     max
# Beats.Per.Minute  190.0
# Energy             88.0
# Danceability       90.0
# Loudness..dB..     -2.0
# Liveness           58.0
# Valence.           95.0
# Length.           309.0
# Acousticness..     75.0
# Speechiness.       46.0
# Popularity         95.0

# %%
data=data.loc[:49,:]

# %%
#Rename Column
data=data.rename(columns={"Loudness..dB..": "Loudness", 
                          "Acousticness..": "Acousticness",
                          "Speechiness.":"Speechiness",
                          "Valence.":"Valence",
                          "Length.":"Length"})

# %%
final=data.copy()

# %%
#Correlation Matrix Between Numeric Features
plt.figure(figsize = (16,7))

corrMatrix = final.corr()
sns.heatmap(corrMatrix, annot=True, linewidths=.5);

# %%
#Grouping Some Features According To Genre
a=final[['Genre', 'Popularity','Energy', 'Length','Liveness','Acousticness']].groupby(
    ['Genre'], as_index=False).mean().sort_values(by='Energy', ascending=True)
a
# Out:
#                Genre  Popularity     Energy      Length   Liveness  \
# 11        electropop   92.000000  44.000000  194.500000  11.000000
# 5   canadian hip hop   89.666667  45.000000  193.000000  15.000000
# 9            dfw rap   92.500000  56.500000  166.500000   9.000000
# 0        atl hip hop   89.000000  59.000000  200.000000  13.000000
# 1     australian pop   83.000000  59.000000  210.000000  18.000000
# 8          dance pop   85.750000  59.875000  202.625000  15.500000
# 7        country rap   89.000000  60.500000  136.000000  11.500000
# 12       escape room   91.000000  62.000000  173.000000  12.000000
# 10               edm   86.666667  63.000000  218.666667  20.333333
# 15               pop   85.857143  63.285714  195.428571  12.142857
# 20        trap music   92.000000  64.000000  131.000000   7.000000
# 18         reggaeton   91.000000  66.500000  213.500000  16.500000
# 17    r&b en espanol   88.000000  69.000000  162.000000   5.000000
# 4            brostep   88.000000  70.500000  198.000000  37.500000
# 2           big room   89.000000  72.000000  164.000000  14.000000
# 3           boy band   80.000000  73.000000  181.000000  11.000000
# 16         pop house   91.000000  74.000000  153.000000   7.000000
# 14    panamanian pop   89.000000  74.500000  257.000000   8.500000
# 13             latin   89.800000  76.600000  225.200000  21.000000
# 19    reggaeton flow   87.500000  80.000000  305.500000   8.500000
# 6       canadian pop   70.000000  82.000000  191.000000  13.000000
#
#     Acousticness
# 11     29.000000
# 5      21.666667
# 9      50.500000
# 0       2.000000
# 1      69.000000
# 8      27.000000
# 7      19.500000
# 12     11.000000
# 10     12.333333
# 15     21.428571
# 20      2.000000
# 18     41.000000
# 17     39.000000
# 4      13.000000
# 2      18.000000
# 3       4.000000
# 16      4.000000
# 14     10.500000
# 13     17.800000
# 19     11.000000
# 6      49.000000

# %%
sorted_energy=final.sort_values(by=['Energy'])

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=sorted_energy['Energy'],
    y=sorted_energy['Loudness'],
    name="Energy and Loudness"       # this sets its legend entry
))


fig.add_trace(go.Scatter(
    x=sorted_energy['Energy'],
    y=sorted_energy['Acousticness'],
    name="Energy and Acousticness"
))

fig.update_layout(
    title="Acousticness-Loudness values according to Energy",
    xaxis_title="Energy",
    font=dict(
        family="Courier New, monospace",
        size=12,
        color="#7f7f7f"
    )
)

fig.show()
# Out:
# <div>                            <div id="ac9acd0f-da67-4236-a6bf-36d8e4087bcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac9acd0f-da67-4236-a6bf-36d8e4087bcb")) {                    Plotly.newPlot(                        "ac9acd0f-da67-4236-a6bf-36d8e4087bcb",                        [{"name":"Energy and Loudness","x":[32.0,39.0,39.0,40.0,41.0,43.0,45.0,45.0,46.0,48.0,50.0,51.0,56.0,59.0,59.0,59.0,62.0,62.0,62.0,62.0,64.0,65.0,65.0,65.0,68.0,68.0,68.0,68.0,69.0,70.0,70.0,71.0,71.0,72.0,73.0,74.0,75.0,78.0,79.0,79.0,79.0,79.0,79.0,80.0,81.0,82.0,82.0,86.0,88.0],"y":[-11.0,-6.0,-8.0,-9.0,-6.0,-11.0,-7.0,-11.0,-7.0,-6.0,-4.0,-8.0,-6.0,-7.0,-6.0,-6.0,-2.0,-3.0,-5.0,-6.0,-6.0,-4.0,-8.0,-6.0,-6.0,-5.0,-5.0,-7.0,-4.0,-5.0,-6.0,-5.0,-4.0,-7.0,-5.0,-7.0,-4.0,-4.0,-6.0,-3.0,-2.0,-4.0,-4.0,-4.0,-4.0,-5.0,-4.0,-3.0,-5.0],"type":"scatter"},{"name":"Energy and Acousticness","x":[32.0,39.0,39.0,40.0,41.0,43.0,45.0,45.0,46.0,48.0,50.0,51.0,56.0,59.0,59.0,59.0,62.0,62.0,62.0,62.0,64.0,65.0,65.0,65.0,68.0,68.0,68.0,68.0,69.0,70.0,70.0,71.0,71.0,72.0,73.0,74.0,75.0,78.0,79.0,79.0,79.0,79.0,79.0,80.0,81.0,82.0,82.0,86.0,88.0],"y":[59.0,37.0,18.0,5.0,75.0,33.0,12.0,25.0,37.0,56.0,10.0,12.0,48.0,2.0,69.0,34.0,7.0,11.0,60.0,5.0,2.0,45.0,12.0,15.0,1.0,15.0,9.0,2.0,39.0,14.0,23.0,22.0,28.0,18.0,4.0,4.0,24.0,36.0,21.0,19.0,7.0,3.0,14.0,12.0,8.0,13.0,49.0,11.0,19.0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777 ...

# %% [markdown]
# As you can see above, while there is an negative relationship between Energy and Acousticness, there is a positive relationship between Energy and Loudness.

# %%
import plotly.express as px

fig = px.bar(a, x='Genre', y='Popularity',
             hover_data=['Energy', 'Length'],
             color='Energy',height=400)

fig.update_layout(
    title="Popularity and energy comparison by Genre",
    font=dict(
        family="Courier New, monospace",
        size=12,
        color="#7f7f7f"
    )
)

fig.show()
# Out:
# <div>                            <div id="edaa1a67-0982-4317-94d1-526f9c22a46b" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edaa1a67-0982-4317-94d1-526f9c22a46b")) {                    Plotly.newPlot(                        "edaa1a67-0982-4317-94d1-526f9c22a46b",                        [{"alignmentgroup":"True","customdata":[[44.0,194.5],[45.0,193.0],[56.5,166.5],[59.0,200.0],[59.0,210.0],[59.875,202.625],[60.5,136.0],[62.0,173.0],[63.0,218.66666666666666],[63.285714285714285,195.42857142857142],[64.0,131.0],[66.5,213.5],[69.0,162.0],[70.5,198.0],[72.0,164.0],[73.0,181.0],[74.0,153.0],[74.5,257.0],[76.6,225.2],[80.0,305.5],[82.0,191.0]],"hovertemplate":"Genre=%{x}<br>Popularity=%{y}<br>Energy=%{marker.color}<br>Length=%{customdata[1]}<extra></extra>","legendgroup":"","marker":{"color":[44.0,45.0,56.5,59.0,59.0,59.875,60.5,62.0,63.0,63.285714285714285,64.0,66.5,69.0,70.5,72.0,73.0,74.0,74.5,76.6,80.0,82.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["electropop","canadian hip hop","dfw rap","atl hip hop","australian pop","dance pop","country rap","escape room","edm","pop","trap music","reggaeton","r&b en espanol","brostep","big room","boy band","pop house","panamanian pop","latin","reggaeton flow","canadian pop"],"xaxis":"x","y":[92.0,89.66666666666667,92.5,89.0,83.0,85.75,89.0,91.0,86.66666666666667,85.85714285714286,92.0,91.0,88.0,88.0,89.0,80.0,91.0,89.0,89.8,87.5,70.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0 ...

# %%
fig = px.bar(a, y='Acousticness', x='Genre').update_xaxes(categoryorder='total ascending')

fig.update_layout(
    title="Acousticness comparison by Genre",
    font=dict(
        family="Courier New, monospace",
        size=12,
        color="#7f7f7f"
    )
)
fig.show()
# Out:
# <div>                            <div id="6ac4d275-de73-460f-b372-8292ead6d2d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ac4d275-de73-460f-b372-8292ead6d2d7")) {                    Plotly.newPlot(                        "6ac4d275-de73-460f-b372-8292ead6d2d7",                        [{"alignmentgroup":"True","hovertemplate":"Genre=%{x}<br>Acousticness=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["electropop","canadian hip hop","dfw rap","atl hip hop","australian pop","dance pop","country rap","escape room","edm","pop","trap music","reggaeton","r&b en espanol","brostep","big room","boy band","pop house","panamanian pop","latin","reggaeton flow","canadian pop"],"xaxis":"x","y":[29.0,21.666666666666668,50.5,2.0,69.0,27.0,19.5,11.0,12.333333333333334,21.428571428571427,2.0,41.0,39.0,13.0,18.0,4.0,4.0,10.5,17.8,11.0,49.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outli ...

# %%
#Add to new column according to Genre

final['GeneralGenre']=['hip hop' if each =='atl hip hop'
                      else 'hip hop' if each =='canadian hip hop'
                      else 'hip hop' if each == 'trap music'
                      else 'pop' if each == 'australian pop'
                      else 'pop' if each == 'boy band'
                      else 'pop' if each == 'canadian pop'
                      else 'pop' if each == 'dance pop'
                      else 'pop' if each == 'panamanian pop'
                      else 'pop' if each == 'pop'
                      else 'pop' if each == 'pop house'
                      else 'electronic' if each == 'big room'
                      else 'electronic' if each == 'brostep'
                      else 'electronic' if each == 'edm'
                      else 'electronic' if each == 'electropop'
                      else 'rap' if each == 'country rap'
                      else 'rap' if each == 'dfw rap'
                      else 'hip hop' if each == 'hip hop'
                      else 'latin' if each == 'latin'
                      else 'r&b' if each == 'r&n en espanol'
                      else 'raggae' for each in final['Genre']]

# %%
# histogram
final.hist()
plt.gcf().set_size_inches(15, 15)    #Thanks to this graphic, we can see the feature is right or left skewed.
plt.show()

from pandas.plotting import scatter_matrix

# scatter plot matrix
scatter_matrix(final)
plt.gcf().set_size_inches(15, 15)
plt.show()

# %%
color_list = ['red' if i=='electronic' 
              else 'green' if i=='escape room' 
              else 'blue' if i == 'hip hop' 
              else 'purple' if i == 'latin'
              else 'darksalmon' if i == 'pop'
              else 'darkcyan' if i == 'raggae'
              else 'greenyellow' for i in final.loc[:,'Genre']]
pd.plotting.scatter_matrix(final.loc[:,['Energy','Danceability','Length','Popularity']],
                                       c=color_list,
                                       figsize= [15,15],
                                       diagonal='hist',
                                       alpha=1,
                                       s = 200,
                                       marker = '+',
                                       edgecolor= "black")
plt.show()

# %%
import plotly.express as px

fig = px.scatter(final, x="Beats.Per.Minute", y="Valence",size='Acousticness'
                 ,color="GeneralGenre")
fig.show()
# Out:
# <div>                            <div id="97d8df11-5444-422a-b292-8cba0c2159d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97d8df11-5444-422a-b292-8cba0c2159d5")) {                    Plotly.newPlot(                        "97d8df11-5444-422a-b292-8cba0c2159d5",                        [{"hovertemplate":"GeneralGenre=raggae<br>Beats.Per.Minute=%{x}<br>Valence=%{y}<br>Acousticness=%{marker.size}<extra></extra>","legendgroup":"raggae","marker":{"color":"#636efa","size":[8.0,60.0,11.0,14.0,22.0,39.0],"sizemode":"area","sizeref":0.1875,"symbol":"circle"},"mode":"markers","name":"raggae","orientation":"v","showlegend":true,"x":[105.0,176.0,158.0,92.0,96.0,98.0],"xaxis":"x","y":[61.0,24.0,41.0,58.0,68.0,75.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"GeneralGenre=pop<br>Beats.Per.Minute=%{x}<br>Valence=%{y}<br>Acousticness=%{marker.size}<extra></extra>","legendgroup":"pop","marker":{"color":"#EF553B","size":[12.0,12.0,9.0,15.0,28.0,75.0,7.0,12.0,4.0,49.0,69.0,59.0,19.0,14.0,13.0,4.0,48.0,1.0,37.0,5.0,21.0],"sizemode":"area","sizeref":0.1875,"symbol":"circle"},"mode":"markers","name":"pop","orientation":"v","showlegend":true,"x":[190.0,93.0,102.0,111.0,96.0,110.0,176.0,93.0,124.0,124.0,98.0,140.0,100.0,176.0,152.0,138.0,95.0,85.0,96.0,136.0,95.0],"xaxis":"x","y":[70.0,55.0,84.0,35.0,38.0,45.0,76.0,14.0,63.0,87.0,54.0,33.0,39.0,62.0,91.0,95.0,68.0,73.0,32.0,35.0,61.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"GeneralGenre=rap<br>Beats.Per.Minute=%{x}<br>Valence=%{y}<br>Acousticness=%{marker.size}<extra></extra>","legendgroup":"rap","marker":{"color":"#00cc96","size":[45.0,5.0,56.0,34.0],"sizemode":"area","sizeref":0.1875,"symbol":"circle"},"mode":"markers","name":"rap","orientation":"v","showlegend":true,"x":[150.0,136.0,90.0,154.0],"xaxis":"x","y":[18.0,64.0,91.0,48.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"GeneralGenre=hip hop<br>Beats.Per.Minute=%{x}<br>Valence=%{y}<br>Acousticness=%{marker.size}<extra></extra>","legendgroup":"hip hop","marker":{"color":"#ab63fa","size":[2.0,10.0,18.0,37.0,2.0],"sizemode":"area","sizeref":0.1875,"symbol":"circle"},"mode":"markers","name":"hip hop","orientation":"v","showlegend":true,"x":[180.0,101.0,130.0,96.0,98.0],"xaxis":"x","y":[23.0,10.0,50.0,40.0,18.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"GeneralGenre=electronic<br>Beats.Per.Minute=%{x}<br>Valence=%{y}<br>Acousticness=%{marker.size}<extra></extra>","legendgroup":"electronic","marker":{"color":"#FFA15A","size":[33.0,25.0,12.0,18.0,2.0,7.0,19.0,23.0],"sizemode":"area","sizeref":0.1875,"symbol":"circle"},"mode":"markers","name":"electronic","orientation":"v","showlegend":true,"x":[135.0,135.0,85.0,114.0,104.0,88.0,100.0,104.0],"xaxis":"x","y":[56.0,68.0,36.0,32.0,40.0,44.0,67.0,50.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"GeneralGenre=latin<br>Beats.Per.Minute=%{x}<br>Valence=%{y}<br>Acousticness=%{marker.size}<extra></extra>","legendgroup":"latin","marker":{"color":"#19d3f3","size":[15.0,36.0,11.0,3.0,24.0],"sizemode":"area","sizeref":0.1875,"symbol":"circle"},"mode":"markers","name":"latin","orientation":"v","showlegend":true,"x":[176.0,92.0,94.0,93.0,176.0],"xaxis":"x","y":[43.0,80.0,66.0,94.0,80.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogra ...

# %% [markdown]
# For example, this graph shows that the pop genre, which has a high Beats.Per.Minute and Valence values, has low Acousticness value.

# %%
#Box Plot Each Features

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly as py
import plotly.graph_objs as go

init_notebook_mode(connected=True)

trace0 = go.Box(
    y=final['Beats.Per.Minute'],
    name = 'Beats.Per.Minute'
)
trace1 = go.Box(
    y=final['Energy'],
    name = 'Energy'
)
trace2 = go.Box(
    y=final['Danceability'],
    name = 'Danceability'
)
trace3 = go.Box(
    y=final['Loudness'],
    name = 'Loudness'
)
trace4 = go.Box(
    y=final['Liveness'],
    name = 'Liveness'
)
trace5 = go.Box(
    y=final['Valence'],
    name = 'Valence'
)
trace6 = go.Box(
    y=final['Loudness'],
    name = 'Loudness'
)
trace7 = go.Box(
    y=final['Length'],
    name = 'Length'
)
trace8 = go.Box(
    y=final['Acousticness'],
    name = 'Acousticness'
)
trace9 = go.Box(
    y=final['Speechiness'],
    name = 'Speechiness'
)
trace10 = go.Box(
    y=final['Popularity'],
    name = 'Popularity'
)
data = [trace0, trace1, trace2, trace3, trace4, trace5, trace6, trace7, trace8,trace9,trace10]

fig = go.Figure(data=data)

py.offline.iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="e9fcb8c9-3ea7-4cc4-8429-5f9c72059913" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9fcb8c9-3ea7-4cc4-8429-5f9c72059913")) {                    Plotly.newPlot(                        "e9fcb8c9-3ea7-4cc4-8429-5f9c72059913",                        [{"name":"Beats.Per.Minute","y":[105.0,190.0,93.0,150.0,102.0,180.0,111.0,136.0,135.0,176.0,96.0,110.0,176.0,101.0,93.0,176.0,90.0,130.0,158.0,124.0,154.0,92.0,92.0,135.0,124.0,98.0,96.0,94.0,93.0,85.0,140.0,96.0,98.0,100.0,114.0,176.0,152.0,138.0,95.0,104.0,85.0,96.0,136.0,98.0,88.0,176.0,100.0,104.0,95.0],"type":"box"},{"name":"Energy","y":[81.0,80.0,65.0,65.0,68.0,64.0,68.0,62.0,43.0,62.0,71.0,41.0,79.0,50.0,45.0,65.0,48.0,39.0,62.0,74.0,59.0,79.0,78.0,45.0,82.0,59.0,46.0,86.0,79.0,51.0,32.0,71.0,59.0,88.0,72.0,70.0,82.0,73.0,56.0,68.0,68.0,39.0,40.0,69.0,62.0,75.0,79.0,70.0,79.0],"type":"box"},{"name":"Danceability","y":[79.0,40.0,64.0,58.0,80.0,75.0,48.0,88.0,70.0,61.0,82.0,50.0,73.0,83.0,70.0,75.0,76.0,84.0,72.0,68.0,70.0,81.0,80.0,67.0,69.0,82.0,73.0,74.0,64.0,29.0,78.0,78.0,80.0,77.0,66.0,75.0,72.0,84.0,81.0,69.0,77.0,57.0,90.0,88.0,66.0,67.0,69.0,59.0,75.0],"type":"box"},{"name":"Loudness","y":[-4.0,-4.0,-8.0,-4.0,-5.0,-6.0,-5.0,-6.0,-11.0,-5.0,-4.0,-6.0,-2.0,-4.0,-7.0,-6.0,-6.0,-8.0,-3.0,-7.0,-6.0,-4.0,-4.0,-11.0,-4.0,-6.0,-7.0,-3.0,-4.0,-8.0,-11.0,-5.0,-7.0,-5.0,-7.0,-5.0,-5.0,-5.0,-6.0,-7.0,-6.0,-6.0,-9.0,-4.0,-2.0,-4.0,-3.0,-6.0,-6.0],"type":"box"},{"name":"Liveness","y":[8.0,16.0,8.0,11.0,9.0,7.0,8.0,11.0,10.0,24.0,15.0,11.0,6.0,12.0,16.0,11.0,7.0,14.0,12.0,7.0,12.0,9.0,44.0,12.0,13.0,18.0,19.0,6.0,36.0,10.0,9.0,9.0,13.0,32.0,14.0,11.0,36.0,11.0,6.0,10.0,7.0,23.0,6.0,5.0,58.0,8.0,17.0,41.0,7.0],"type":"box"},{"name":"Valence","y":[61.0,70.0,55.0,18.0,84.0,23.0,35.0,64.0,56.0,24.0,38.0,45.0,76.0,10.0,14.0,43.0,91.0,50.0,41.0,63.0,48.0,58.0,80.0,68.0,87.0,54.0,40.0,66.0,94.0,36.0,33.0,68.0,18.0,39.0,32.0,62.0,91.0,95.0,68.0,40.0,73.0,32.0,35.0,75.0,44.0,80.0,67.0,50.0,61.0],"type":"box"},{"name":"Loudness","y":[-4.0,-4.0,-8.0,-4.0,-5.0,-6.0,-5.0,-6.0,-11.0,-5.0,-4.0,-6.0,-2.0,-4.0,-7.0,-6.0,-6.0,-8.0,-3.0,-7.0,-6.0,-4.0,-4.0,-11.0,-4.0,-6.0,-7.0,-3.0,-4.0,-8.0,-11.0,-5.0,-7.0,-5.0,-7.0,-5.0,-5.0,-5.0,-6.0,-7.0,-6.0,-6.0,-9.0,-4.0,-2.0,-4.0,-3.0,-6.0,-6.0],"type":"box"},{"name":"Length","y":[302.0,186.0,198.0,175.0,220.0,131.0,202.0,157.0,194.0,251.0,185.0,182.0,288.0,205.0,261.0,243.0,158.0,161.0,173.0,153.0,115.0,309.0,266.0,195.0,191.0,210.0,213.0,193.0,222.0,210.0,179.0,176.0,200.0,224.0,164.0,226.0,162.0,181.0,199.0,228.0,171.0,216.0,198.0,162.0,182.0,202.0,214.0,218.0,206.0],"type":"box"},{"name":"Acousticness","y":[8.0,12.0,12.0,45.0,9.0,2.0,15.0,5.0,33.0,60.0,28.0,75.0,7.0,10.0,12.0,15.0,56.0,18.0,11.0,4.0,34.0,14.0,36.0,25.0,49.0,69.0,37.0,11.0,3.0,12.0,59.0,22.0,2.0,19.0,18.0,14.0,13.0,4.0,48.0,2.0,1.0,37.0,5.0,39.0,7.0,24.0,19.0,23.0,21.0],"type":"box"},{"name":"Speechiness","y":[9.0,46.0,19.0,7.0,4.0,29.0,9.0,10.0,38.0,31.0,7.0,3.0,20.0,5.0,15.0,32.0,5.0,8.0,11.0,3.0,8.0,7.0,4.0,30.0,6.0,10.0,3.0,6.0,25.0,4.0,33.0,28.0,15.0,6.0,6.0,34.0,5.0,6.0,7.0,3.0,5.0,3.0,13.0,12.0,5.0,6.0,5.0,3.0,12.0],"type":"box"},{"name":"Popularity","y":[92.0,85.0,86.0,94.0,84.0,92.0,90.0,87.0,95.0,93.0,86.0,88.0,87.0,92.0,82.0,90.0,91.0,88.0,91.0,91.0,91.0,83.0,91.0,89.0,70.0,83.0,89.0,91.0,89.0,84.0,89.0,89.0,89.0,89.0,89.0,91.0,87.0,80.0,78.0,88.0,90.0,87.0,84.0,88.0,88.0,88.0,88.0,88.0,82.0],"type":"box"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5}, ...

# %%
pd=pd.DataFrame(final['Genre'].value_counts())
pd.head(2)
# Out:
#            Genre
# dance pop      8
# pop            7

# %%
pd.rename(columns={"Genre": "Count"},inplace=True)
pd['Genre'] = pd.index
pd['Ratio'] = pd['Count']/pd['Count'].sum() #Add count ratio for each genre

# %%
pd.head()
# Out:
#                   Count             Genre     Ratio
# dance pop             8         dance pop  0.163265
# pop                   7               pop  0.142857
# latin                 5             latin  0.102041
# edm                   3               edm  0.061224
# canadian hip hop      3  canadian hip hop  0.061224

# %%
pd['Ratio'] = pd['Ratio'].astype(float)

# %%
import matplotlib.colors as colors
labels_list = pd['Genre']
colors_list = list(colors._colors_full_map.values())

# Plot
plt.figure(figsize=(20,10))
plt.pie(pd['Ratio'], colors=colors_list[0:20],
autopct='%1.1f%%', shadow=True, startangle=50,
       labels=labels_list)

plt.axis('equal')
plt.title('Distribution of the % of Genre')
plt.show()

# %% [markdown]
# K-Means Clustering

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 1 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track.Name        49 non-null     object
#  1   Artist.Name       49 non-null     object
#  2   Genre             49 non-null     object
#  3   Beats.Per.Minute  49 non-null     float64
#  4   Energy            49 non-null     float64
#  5   Danceability      49 non-null     float64
#  6   Loudness          49 non-null     float64
#  7   Liveness          49 non-null     float64
#  8   Valence           49 non-null     float64
#  9   Length            49 non-null     float64
#  10  Acousticness      49 non-null     float64
#  11  Speechiness       49 non-null     float64
#  12  Popularity        49 non-null     float64
#  13  GeneralGenre      49 non-null     object
# dtypes: float64(10), object(4)
# memory usage: 5.7+ KB

# %%
final2=final.drop(columns=['Track.Name', 'Artist.Name', 'GeneralGenre', 'Genre'])

# %%
final2.head()
# Out:
#             Beats.Per.Minute  Energy  Danceability  Loudness  Liveness  \
# Unnamed: 0
# 1                      105.0    81.0          79.0      -4.0       8.0
# 2                      190.0    80.0          40.0      -4.0      16.0
# 3                       93.0    65.0          64.0      -8.0       8.0
# 4                      150.0    65.0          58.0      -4.0      11.0
# 5                      102.0    68.0          80.0      -5.0       9.0
#
#             Valence  Length  Acousticness  Speechiness  Popularity
# Unnamed: 0
# 1              61.0   302.0           8.0          9.0        92.0
# 2              70.0   186.0          12.0         46.0        85.0
# 3              55.0   198.0          12.0         19.0        86.0
# 4              18.0   175.0          45.0          7.0        94.0
# 5              84.0   220.0           9.0          4.0        84.0

# %%
#Rename Column
final2=final2.rename(columns={"Beats.Per.Minute": "BeatsPerMinute"})

# %%
#Standardizing to all data

from sklearn.preprocessing import StandardScaler
final2[['BeatsPerMinute', 'Energy',
        'Danceability','Loudness',
        'Liveness','Valence',
        'Length','Acousticness',
        'Speechiness','Popularity']] = StandardScaler().fit_transform(final2[['BeatsPerMinute','Energy',
                                                                              'Danceability','Loudness',
                                                                              'Liveness','Valence',
                                                                              'Length','Acousticness',
                                                                              'Speechiness','Popularity']])

# %%
final2.tail()
# Out:
#             BeatsPerMinute    Energy  Danceability  Loudness  Liveness  \
# Unnamed: 0
# 45               -1.039722 -0.158407     -0.443759  1.776899  3.900451
# 46                1.808614  0.758912     -0.359804  0.804072 -0.613533
# 47               -0.651312  1.041164     -0.191896  1.290485  0.198984
# 48               -0.521843  0.406097     -1.031439 -0.168756  2.365696
# 49               -0.813150  1.041164      0.311830 -0.168756 -0.703813
#
#              Valence    Length  Acousticness  Speechiness  Popularity
# Unnamed: 0
# 45         -0.459943 -0.489890     -0.825485    -0.692711    0.075573
# 46          1.165987  0.021390      0.078101    -0.602438    0.075573
# 47          0.578846  0.328159     -0.187660    -0.692711    0.075573
# 48         -0.188954  0.430415      0.024949    -0.873258    0.075573
# 49          0.307858  0.123646     -0.081355    -0.060796   -1.313075

# %%
# KMeans Clustering
# !pip install yellowbrick
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
# Out:
# Requirement already satisfied: yellowbrick in d:\anaconda\lib\site-packages (1.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in d:\anaconda\lib\site-packages (from yellowbrick) (3.7.0)
# Requirement already satisfied: scipy>=1.0.0 in d:\anaconda\lib\site-packages (from yellowbrick) (1.10.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in d:\anaconda\lib\site-packages (from yellowbrick) (1.3.0)
# Requirement already satisfied: numpy>=1.16.0 in d:\anaconda\lib\site-packages (from yellowbrick) (1.23.5)
# Requirement already satisfied: cycler>=0.10.0 in d:\anaconda\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in d:\anaconda\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (2.2.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda\lib\site-packages)

# %%
kmeans=KMeans()

# %%
visualizer=KElbowVisualizer(kmeans, k=(2,10))
visualizer.fit(final2)
visualizer.poof()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
# PCA variance
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline


scaler = StandardScaler()
pca = PCA()
pipeline = make_pipeline(scaler,pca)
pipeline.fit(final2)

plt.bar(range(pca.n_components_), pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=7)
kmeans
# Out:
# KMeans(n_clusters=7)

# %%
k_fit=kmeans.fit(final2)

# %%
clusters=k_fit.labels_
clusters
# Out:
# array([5, 2, 3, 2, 6, 2, 3, 6, 0, 2, 6, 0, 2, 3, 3, 2, 6, 0, 2, 6, 0, 5,
#        1, 0, 4, 4, 3, 6, 1, 3, 0, 6, 3, 1, 3, 2, 1, 6, 4, 3, 6, 3, 0, 6,
#        1, 2, 6, 1, 6])

# %%
final2['segment']=clusters+1
final2.head()
# Out:
#             BeatsPerMinute    Energy  Danceability  Loudness  Liveness  \
# Unnamed: 0
# 1                -0.489475  1.182290      0.647648  0.804072 -0.613533
# 2                 2.261758  1.111727     -2.626572  0.804072  0.108704
# 3                -0.877885  0.053282     -0.611667 -1.141583 -0.613533
# 4                 0.967060  0.053282     -1.115393  0.804072 -0.342694
# 5                -0.586577  0.264971      0.731602  0.317658 -0.523254
#
#              Valence    Length  Acousticness  Speechiness  Popularity  segment
# Unnamed: 0
# 1           0.307858  2.577792     -0.772333    -0.331617    1.001338        6
# 2           0.714340 -0.387634     -0.559725     3.008504   -0.618751        3
# 3           0.036869 -0.080866     -0.559725     0.571118   -0.387310        4
# 4          -1.634226 -0.668838      1.194296    -0.512164    1.464220        3
# 5           1.346646  0.481543     -0.719181    -0.782985   -0.850192        7

# %%
import mpl_toolkits
from mpl_toolkits.mplot3d import Axes3D

centers=kmeans.cluster_centers_

plt.rcParams['figure.figsize'] = (16,9)
fig=plt.figure()

ax=Axes3D(fig)
ax.scatter(final2.iloc[:,0], final2.iloc[:,1], final2.iloc[:,2]);

# %%
joined_df_merge = final2.merge(final, how='left', 
                                      left_index=True,
                                      right_index=True)

# %%
joined_df_merge[['segment','Genre','GeneralGenre']]
# Out:
#             segment             Genre GeneralGenre
# Unnamed: 0
# 1                 6    reggaeton flow       raggae
# 2                 3         dance pop          pop
# 3                 4               pop          pop
# 4                 3           dfw rap          rap
# 5                 7               pop          pop
# 6                 3        trap music      hip hop
# 7                 4               pop          pop
# 8                 7       country rap          rap
# 9                 1        electropop   electronic
# 10                3         reggaeton       raggae
# 11                7         dance pop          pop
# 12                1               pop          pop
# 13                3    panamanian pop          pop
# 14                4  canadian hip hop      hip hop
# 15                4         dance pop          pop
# 16                3             latin        latin
# 17                7           dfw rap          rap
# 18                1  canadian hip hop      hip hop
# 19                3       escape room       raggae
# 20                7         pop house          pop
# 21                1       country rap          rap
# 22                6    reggaeton flow       raggae
# 23                2             latin        latin
# 24                1        electropop   electronic
# 25                5      canadian pop          pop
# 26                5    australian pop          pop
# 27                4  canadian hip hop      hip hop
# 28                7             latin        latin
# 29                2             latin        latin
# 30                4               edm   electronic
# 31                1         dance pop          pop
# 32                7         reggaeton       raggae
# 33                4       atl hip hop      hip hop
# 34                2         dance pop          pop
# 35                4          big room   electronic
# 36                3    panamanian pop          pop
# 37                2               pop          pop
# 38                7          boy band          pop
# 39                5         dance pop          pop
# 40                4               edm   electronic
# 41                7         dance pop          pop
# 42                4         dance pop          pop
# 43                1               pop          pop
# 44                7    r&b en espanol       raggae
# 45                2           brostep   electronic
# 46                3             latin        latin
# 47                7           brostep   electronic
# 48                2               edm   electronic
# 49                7               pop          pop

# %% [markdown]
# Unsupervised - Hierarchy

# %%
from scipy.cluster.hierarchy import linkage,dendrogram

merg = linkage(final2,method = 'single')
dendrogram(merg, leaf_rotation = 90, leaf_font_size =5)
plt.show()
